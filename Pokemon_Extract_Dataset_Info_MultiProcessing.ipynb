# %%
from PIL import Image
import numpy
from sklearn.cluster import MiniBatchKMeans
import multiprocessing as mp
from functools import partial
from itertools import repeat
import os
import json
import time

'''
Quelques notes :

k-Means : 
 * cet algorithme permet de rechercher un nombre prédéterminé (NB_CLUSTER)
de grappes (appelé cluster) dans une image (dans notre application). 
 * le centre de chaque grappe est la moyenne arithmétique de tous les points appartenant à la grappe
'''
## Temps d'éxécutions
# KMeans environ  : 160s pour 70 fichiers
# MiniBatchKMeans : 70s pour 70 fichiers

# Settings dataset folders
POKE_DATA_DIRECTORY = '../datasets/pokedata'
POKE_DATA_DIRECTORY_TEST = POKE_DATA_DIRECTORY+'/Muk'

# Nombre de valeur K-MEANS
NB_CLUSTER = 3


#########################################################################################################
# 
# Cette classe permet de récupérer le chemin (os) des fichiers d'un dossier et/ou de ses sous répertoires
#
class LocalDataset:
    subDirectories = [] # Contient le chemin de sous dossier
    files = []
    dictionnary = {}
    countFiles = 0
    
    def __init__(self,rootDirectory,subDirectory=None):
        self.rootDirectory = rootDirectory
        if subDirectory == None:
            self.setPathSubDirectory()
        else:
            self.subDirectories.append(subDirectory)
        self.setDictFolderFiles()
        
    def setPathSubDirectory(self):
        for directory in os.listdir(self.rootDirectory):
            self.subDirectories.append(self.rootDirectory+'/'+directory)
            
    def setDictFolderFiles(self):
        for subRep in self.subDirectories:
            name = subRep.split('/')
            name = name[-1]
            self.dictionnary[name] = []
            for file in os.listdir(subRep):
                if (not(".svg" in file)):
                    self.dictionnary[name].append(subRep+"/"+file)
                    self.files.append(subRep+'/'+file)
                    self.countFiles +=1
    
    def getDictFolderFiles(self):
        return self.dictionnary

    def getSubDirectories(self):
        return self.subDirectories
    
    def getCountFiles(self):
        return self.countFiles
#
#
#########################################################################################################



#########################################################################################################
# 
# Cette classe d'enregistrer un dictionnaire dans un fichier json
#
class JSONWriter:
    def __init__(self, filePath):
        self.filePath = filePath

    def writeJSON(self, data):
        with open(self.filePath, 'w') as f:
            json.dump(data, f)
#
#
#########################################################################################################
 

           
#########################################################################################################
# 
# Cette classe permet gérer la création de nos images
#
class ImageManager:
    def __init__(self):
        self.images = []
    
    # Création d'une image et sauvegarde de sa référence
    def addImage(self, name, imgPath):
        self.images.append(ImageP(name,imgPath))
          
    def getImages(self):
        return self.images
#
#
#########################################################################################################   



#########################################################################################################
# 
# Cette classe représente nos images
#
class ImageP:
    
    
    def __init__(self, name, path):
        self.name = name # nom du pokemon -> nom du dossier
        self.path = path # chemin de l'image
        self.clusterCenters = {} # centre des NB_CLUSTER grappes
        self.format = None 
        self.size = None # size -> (width,height)

    
    def setKmeans(self,cluster_centers):
        self.clusterCenters["colors"]=[]
        for color in cluster_centers:
            self.clusterCenters["colors"].append({"red":color[0], "green":color[1], "blue":color[2]})
    
    def setFormat(self, imageFormat):
        self.format = imageFormat
    
    def setSize(self, size):
        self.size = size
    
    def toDict(self):
        imageDict = {}
        imageDict["name"]= self.name
        imageDict["path"] = self.path
        imageDict["colors"] = []
        
        for color in self.clusterCenters:
            imageDict["colors"].append({"red":color[0], "green":color[1], "blue":color[2]})

        imageDict["size"] = self.size
        imageDict["format"] = self.format
        
        return imageDict
        
        
        
#
#
#########################################################################################################



# Cette fonction calcule les k-means valeurs pour NB_CLUSTER grappes
def processingKmeans(image,return_list):
    print("-> Processing image : "+image.path)
    
    im = Image.open(image.path) # Création objet PIL
    
    image.setFormat(im.format) # Définit le format de l'objet image
    image.setSize(im.size) # Définit la taille de l'objet image
    
    
    numarray = numpy.array(im.getdata(), numpy.uint8) # Création array pixel rgb
    dim = numarray.ndim # Dimension de l'array
    
    if dim == 2: # clusters.fit n'accepte pas les images à 1 dimension
        clusters = MiniBatchKMeans(n_clusters = NB_CLUSTER)
        clusters.fit(numarray)
        image.setKmeans(clusters.cluster_centers_)
        
        return_list.append(image)
        print("Done process :"+image.path)
        

        
# Lancement du chronomètre
startTime = time.time()


# Initialisation des données
dataset = LocalDataset(POKE_DATA_DIRECTORY,POKE_DATA_DIRECTORY_TEST)
allFiles = dataset.files


# Initialisation des objets images
imageManager = ImageManager()
images = []

for file in allFiles:
    pokemonName=file.split('/')
    imageManager.addImage(pokemonName[-1],file)

images = imageManager.getImages()
print("Nombre d'images à traiter : ",len(images))

    
# Initialisation du multiprocessing
processingManager = mp.Manager()
return_list_image = processingManager.list()
pool = mp.Pool(processes=4)


# Création / Lancement des processus
pool.starmap(processingKmeans, zip(images, repeat(return_list_image)))


# Préparation des données à exporter
exportData = []
for image in return_list_image:
    exportData.append(image.toDict())

# Export des données en JSON
jw = JSONWriter("./datasets/data.json") # Fichier de sortie

print("Running -> Object to JSON ...")
jw.writeJSON(exportData)
print("Done -> Object to JSON ...")


# Arrêt du chronomètre
endTime = time.time()
totalTime = endTime - startTime
print("Total time: ", totalTime)
# Out:
# Nombre d'images à traiter :  71
# -> Processing image : ../datasets/pokedata/Muk/d97fccb731a84cdc9c3872e9b0396fbe.jpg
# -> Processing image : ../datasets/pokedata/Muk/620187e98117499694d16d11c6992264.jpg
# -> Processing image : ../datasets/pokedata/Muk/f393f240104646849ef3121a0b13660d.jpg
# -> Processing image : ../datasets/pokedata/Muk/726d39a4959a4bf3b0b81105bf739b56.jpg
# Done process :../datasets/pokedata/Muk/726d39a4959a4bf3b0b81105bf739b56.jpg
# -> Processing image : ../datasets/pokedata/Muk/7b60685b53454ffc9647d9b4fb073249.jpg
# Done process :../datasets/pokedata/Muk/f393f240104646849ef3121a0b13660d.jpg
# -> Processing image : ../datasets/pokedata/Muk/f70664da7b154e469a52e6bcbb7ddac0.jpg
# Done process :../datasets/pokedata/Muk/f70664da7b154e469a52e6bcbb7ddac0.jpg
# -> Processing image : ../datasets/pokedata/Muk/db7686074ea14fc18f4a8e7ad1b1aada.jpg
# Done process :../datasets/pokedata/Muk/db7686074ea14fc18f4a8e7ad1b1aada.jpg
# -> Processing image : ../datasets/pokedata/Muk/020b12c6be0744d8ac3e3b4cbdd1fc34.jpg
# Done process :../datasets/pokedata/Muk/d97fccb731a84cdc9c3872e9b0396fbe.jpg
# -> Processing image : ../datasets/pokedata/Muk/5e0901af36d542e6aa5caf4be52033ef.jpg
# Done process :../datasets/pokedata/Muk/020b12c6be0744d8ac3e3b4cbdd1fc34.jpg
# -> Processing image : ../datasets/pokedata/Muk/df3003cb06004372b7e899df26745932.jpg
# Done process :../datasets/pokedata/Muk/5e0901af36d542e6aa5caf4be52033ef.jpg
# -> Processing image : ../datasets/pokedata/Muk/cb68471d84004c259e28033a78826263.jpg
# Done process :../datasets/pokedata/Muk/df3003cb06004372b7e899df26745932.jpg
# -> Processing image : ../datasets/pokedata/Muk/91603ce153ea4b988f5776a510648070.jpg
# Done process :../datasets/pokedata/Muk/cb68471d84004c259e28033a78826263.jpg
# -> Processing image : ../datasets/pokedata/Muk/9ad0884fa50f4abba397497c5ec4495f.jpg
# Done process :../datasets/pokedata/Muk/91603ce153ea4b988f5776a510648070.jpg
# -> Processing image : ../datasets/pokedata/Muk/22c016e4ceb84b6e905a226a506c75d8.jpg
# Done process :../datasets/pokedata/Muk/9ad0884fa50f4abba397497c5ec4495f.jpg
# -> Processing image : ../datasets/pokedata/Muk/8befb986702e41358de5be7add429260.jpg
# Done process :../datasets/pokedata/Muk/22c016e4ceb84b6e905a226a506c75d8.jpg
# -> Processing image : ../datasets/pokedata/Muk/c8e5f8a75315486fb7747972e292bd9e.jpg
# Done process :../datasets/pokedata/Muk/7b60685b53454ffc9647d9b4fb073249.jpg
# -> Processing image : ../datasets/pokedata/Muk/46549609739e41c191ec1fba66a3f82c.jpg
# Done process :../datasets/pokedata/Muk/46549609739e41c191ec1fba66a3f82c.jpg
# -> Processing image : ../datasets/pokedata/Muk/59a1538320a341048a2bff3c62cb571f.jpg
# Done process :../datasets/pokedata/Muk/c8e5f8a75315486fb7747972e292bd9e.jpg
# -> Processing image : ../datasets/pokedata/Muk/f91c03844e594c67ae82d5f20cc3c2ad.jpg
# Done process :../datasets/pokedata/Muk/f91c03844e594c67ae82d5f20cc3c2ad.jpg
# -> Processing image : ../datasets/pokedata/Muk/2bed4a3c5dc94e61ba7dd380985fce4b.jpg
# Done process :../datasets/pokedata/Muk/620187e98117499694d16d11c6992264.jpg
# -> Processing image : ../datasets/pokedata/Muk/d4ddd14c1d4340a680018d0b805bd1b2.asp
# Done process :../datasets/pokedata/Muk/d4ddd14c1d4340a680018d0b805bd1b2.asp
# -> Processing image : ../datasets/pokedata/Muk/580891a9214043c098c759668d903419.jpg
# Done process :../datasets/pokedata/Muk/8befb986702e41358de5be7add429260.jpg
# -> Processing image : ../datasets/pokedata/Muk/cbb907e82b6e4e2caa66d2acbefacc1f.jpg
# Done process :../datasets/pokedata/Muk/2bed4a3c5dc94e61ba7dd380985fce4b.jpg
# -> Processing image : ../datasets/pokedata/Muk/1d1644fd721540418a78918a2e902ac7.jpg
# Done process :../datasets/pokedata/Muk/cbb907e82b6e4e2caa66d2acbefacc1f.jpg
# -> Processing image : ../datasets/pokedata/Muk/04bbc53f55724831a9efb0b21b6c8437.jpg
# Done process :../datasets/pokedata/Muk/1d1644fd721540418a78918a2e902ac7.jpg
# -> Processing image : ../datasets/pokedata/Muk/0081109d293d448faf8062b2e7e79549.jpg
# Done process :../datasets/pokedata/Muk/0081109d293d448faf8062b2e7e79549.jpg
# -> Processing image : ../datasets/pokedata/Muk/2009d4daf25a40d582c39205782d4112.jpg
# Done process :../datasets/pokedata/Muk/59a1538320a341048a2bff3c62cb571f.jpg
# -> Processing image : ../datasets/pokedata/Muk/6f5db93c69104a0393f76afcb4479455.jpg
# Done process :../datasets/pokedata/Muk/6f5db93c69104a0393f76afcb4479455.jpg
# -> Processing image : ../datasets/pokedata/Muk/e03de401122c42ce831160a59b0678df-0.jpg
# Done process :../datasets/pokedata/Muk/580891a9214043c098c759668d903419.jpg
# -> Processing image : ../datasets/pokedata/Muk/89ff8305a1da4de98f92ad0f1f3d5179.jpg
# Done process :../datasets/pokedata/Muk/e03de401122c42ce831160a59b0678df-0.jpg
# -> Processing image : ../datasets/pokedata/Muk/9308f153979c4bd7bc6864a687e1179a.jpg
# Done process :../datasets/pokedata/Muk/9308f153979c4bd7bc6864a687e1179a.jpg
# -> Processing image : ../datasets/pokedata/Muk/6f579d2a197f4304a214c8a26c878c26.jpg
# Done process :../datasets/pokedata/Muk/2009d4daf25a40d582c39205782d4112.jpg
# -> Processing image : ../datasets/pokedata/Muk/40125c67270f41c7891ed100268e694a.jpg
# Done process :../datasets/pokedata/Muk/6f579d2a197f4304a214c8a26c878c26.jpg
# -> Processing image : ../datasets/pokedata/Muk/368d1092717d40bb8f1ffc9384e46061.jpg
# Done process :../datasets/pokedata/Muk/89ff8305a1da4de98f92ad0f1f3d5179.jpg
# -> Processing image : ../datasets/pokedata/Muk/108472ab2a60450aa3947ce0011833fa.jpg
# Done process :../datasets/pokedata/Muk/368d1092717d40bb8f1ffc9384e46061.jpg
# -> Processing image : ../datasets/pokedata/Muk/5dfe89ade5a545d9ac4e60d1efb9942e.jpg
# Done process :../datasets/pokedata/Muk/108472ab2a60450aa3947ce0011833fa.jpg
# -> Processing image : ../datasets/pokedata/Muk/1f1e455654024ab198bf53ca0e5ca890.jpg
# Done process :../datasets/pokedata/Muk/40125c67270f41c7891ed100268e694a.jpg
# -> Processing image : ../datasets/pokedata/Muk/b2f1c04bc79a43d98651c1b79bf83170.jpg
# Done process :../datasets/pokedata/Muk/5dfe89ade5a545d9ac4e60d1efb9942e.jpg
# -> Processing image : ../datasets/pokedata/Muk/c64c4713b6794d10b23e7e434d68aa17.jpg
# Done process :../datasets/pokedata/Muk/b2f1c04bc79a43d98651c1b79bf83170.jpg
# -> Processing image : ../datasets/pokedata/Muk/92794379af054aeeb7a40dedea1b51e1.jpg
# Done process :../datasets/pokedata/Muk/c64c4713b6794d10b23e7e434d68aa17.jpg
# -> Processing image : ../datasets/pokedata/Muk/84e6d181d8f341a482d45b4563737e20.jpg
# Done process :../datasets/pokedata/Muk/84e6d181d8f341a482d45b4563737e20.jpg
# -> Processing image : ../datasets/pokedata/Muk/14d725b36ba34b49ad84e60df83365b4.jpg
# Done process :../datasets/pokedata/Muk/14d725b36ba34b49ad84e60df83365b4.jpg
# -> Processing image : ../datasets/pokedata/Muk/666bb43fc55b42eb8b9819e849420fed.jpg
# Done process :../datasets/pokedata/Muk/1f1e455654024ab198bf53ca0e5ca890.jpg
# -> Processing image : ../datasets/pokedata/Muk/8892eef19dc847fb8e4cffa2a451cce2.jpg
# Done process :../datasets/pokedata/Muk/04bbc53f55724831a9efb0b21b6c8437.jpg
# -> Processing image : ../datasets/pokedata/Muk/6cf603bc31c641fe94f2dd3dc289a07c.jpg
# Done process :../datasets/pokedata/Muk/6cf603bc31c641fe94f2dd3dc289a07c.jpg
# -> Processing image : ../datasets/pokedata/Muk/7154380ecbee4c728bc32e69a84001c5.jpg
# Done process :../datasets/pokedata/Muk/7154380ecbee4c728bc32e69a84001c5.jpg
# -> Processing image : ../datasets/pokedata/Muk/be0f8412d6c448ce94c41f5d2bd9abb3.jpg
# Done process :../datasets/pokedata/Muk/92794379af054aeeb7a40dedea1b51e1.jpg
# -> Processing image : ../datasets/pokedata/Muk/318e67eb103146ce99ac1fb655c15a8f.jpg
# Done process :../datasets/pokedata/Muk/666bb43fc55b42eb8b9819e849420fed.jpg
# -> Processing image : ../datasets/pokedata/Muk/d99a419aea0f414a86f5b28d29cf4c6f.jpg
# Done process :../datasets/pokedata/Muk/318e67eb103146ce99ac1fb655c15a8f.jpg
# -> Processing image : ../datasets/pokedata/Muk/e03de401122c42ce831160a59b0678df-1.jpg
# Done process :../datasets/pokedata/Muk/8892eef19dc847fb8e4cffa2a451cce2.jpg
# -> Processing image : ../datasets/pokedata/Muk/71405946b5174b9ea8e3d76f665a3f0f.jpg
# Done process :../datasets/pokedata/Muk/e03de401122c42ce831160a59b0678df-1.jpg
# -> Processing image : ../datasets/pokedata/Muk/e03de401122c42ce831160a59b0678df-3.jpg
# Done process :../datasets/pokedata/Muk/d99a419aea0f414a86f5b28d29cf4c6f.jpg
# -> Processing image : ../datasets/pokedata/Muk/97161eb635bd49fe86329e3064b11c0f.jpg
# Done process :../datasets/pokedata/Muk/97161eb635bd49fe86329e3064b11c0f.jpg
# -> Processing image : ../datasets/pokedata/Muk/ecdf8c79e57947f092c230e298ca92b8.jpg
# Done process :../datasets/pokedata/Muk/e03de401122c42ce831160a59b0678df-3.jpg
# -> Processing image : ../datasets/pokedata/Muk/1b55a4ec96f14690b1d9febdd4540f86.jpg
# Done process :../datasets/pokedata/Muk/1b55a4ec96f14690b1d9febdd4540f86.jpg
# -> Processing image : ../datasets/pokedata/Muk/6551686bda8f4c4081a63a3bac1f3ea3.jpg
# Done process :../datasets/pokedata/Muk/be0f8412d6c448ce94c41f5d2bd9abb3.jpg
# -> Processing image : ../datasets/pokedata/Muk/4d6af95f821440b985af52a3e38a03c1.jpg
# Done process :../datasets/pokedata/Muk/4d6af95f821440b985af52a3e38a03c1.jpg
# -> Processing image : ../datasets/pokedata/Muk/a21e7b5cbe8b4a88adefdd683623c0dc.jpg
# Done process :../datasets/pokedata/Muk/6551686bda8f4c4081a63a3bac1f3ea3.jpg
# -> Processing image : ../datasets/pokedata/Muk/472a38fc09e34d1bace624fc8d002355.jpg
# Done process :../datasets/pokedata/Muk/ecdf8c79e57947f092c230e298ca92b8.jpg
# -> Processing image : ../datasets/pokedata/Muk/3acbf68a9f4e4c738960f80cd9b59181.jpg
# -> Processing image : ../datasets/pokedata/Muk/f8daae91229b41e184a6883cc6c35dae.jpg
# Done process :../datasets/pokedata/Muk/a21e7b5cbe8b4a88adefdd683623c0dc.jpg
# -> Processing image : ../datasets/pokedata/Muk/e03de401122c42ce831160a59b0678df-2.jpg
# Done process :../datasets/pokedata/Muk/71405946b5174b9ea8e3d76f665a3f0f.jpg
# -> Processing image : ../datasets/pokedata/Muk/72d0fe62ccd24bb3a9a83ffeb4b7ceb4.jpg
# Done process :../datasets/pokedata/Muk/e03de401122c42ce831160a59b0678df-2.jpg
# -> Processing image : ../datasets/pokedata/Muk/c32ff24faa7a4f5f8865dba11a522e7d.jpg
# Done process :../datasets/pokedata/Muk/c32ff24faa7a4f5f8865dba11a522e7d.jpg
# -> Processing image : ../datasets/pokedata/Muk/44197a04e3174aadb01558e9c48e570f.jpg
# Done process :../datasets/pokedata/Muk/f8daae91229b41e184a6883cc6c35dae.jpg
# -> Processing image : ../datasets/pokedata/Muk/a1abac63dfd04713b90bf92b72e72cae.jpg
# Done process :../datasets/pokedata/Muk/44197a04e3174aadb01558e9c48e570f.jpg
# -> Processing image : ../datasets/pokedata/Muk/b1ed939971e743c3a5ddea9020e52f88.jpg
# Done process :../datasets/pokedata/Muk/472a38fc09e34d1bace624fc8d002355.jpg
# -> Processing image : ../datasets/pokedata/Muk/984d2a9157a74ec89f908b0e6146d254.jpg
# Done process :../datasets/pokedata/Muk/984d2a9157a74ec89f908b0e6146d254.jpg
# -> Processing image : ../datasets/pokedata/Muk/594a83612df446faa4a960bccb3e541d.jpg
# Done process :../datasets/pokedata/Muk/594a83612df446faa4a960bccb3e541d.jpg
# -> Processing image : ../datasets/pokedata/Muk/78d1613557254ae2834c72c3f25c7522.jpg
# Done process :../datasets/pokedata/Muk/72d0fe62ccd24bb3a9a83ffeb4b7ceb4.jpg
# -> Processing image : ../datasets/pokedata/Muk/46278f89ac0a432e8980bb5ee51806d8.jpg
# Done process :../datasets/pokedata/Muk/a1abac63dfd04713b90bf92b72e72cae.jpg
# Done process :../datasets/pokedata/Muk/78d1613557254ae2834c72c3f25c7522.jpg
# Done process :../datasets/pokedata/Muk/46278f89ac0a432e8980bb5ee51806d8.jpg
# Done process :../datasets/pokedata/Muk/b1ed939971e743c3a5ddea9020e52f88.jpg
# Running -> Object to JSON ...
# Done -> Object to JSON ...
# Total time:  78.03499341011047
